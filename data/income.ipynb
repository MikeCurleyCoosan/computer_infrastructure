# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as pyplot

# %%
df = pd.read_csv('SID18.20241115154528.csv')

# %%
df.head(20)
# Out:
#    STATISTIC                   Statistic Label  TLIST(A1)  Year  C02352V02829  \
# 0   SID18C01  Income of individuals aged 25-59       2023  2023           214
# 1   SID18C01  Income of individuals aged 25-59       2023  2023           214
# 2   SID18C01  Income of individuals aged 25-59       2023  2023           214
# 3   SID18C01  Income of individuals aged 25-59       2023  2023           214
# 4   SID18C01  Income of individuals aged 25-59       2023  2023           214
# 5   SID18C01  Income of individuals aged 25-59       2023  2023           224
# 6   SID18C01  Income of individuals aged 25-59       2023  2023           224
# 7   SID18C01  Income of individuals aged 25-59       2023  2023           224
# 8   SID18C01  Income of individuals aged 25-59       2023  2023           224
# 9   SID18C01  Income of individuals aged 25-59       2023  2023           224
# 10  SID18C01  Income of individuals aged 25-59       2023  2023             4
# ...
